# %% [markdown]
# ## step:01 Importing Libraries and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('01_icc_wc_23_bowl.csv')
df.head()  # to show top 5 scales
# Out:
#                 player  overs  maidens  runs  wickets  run_rate  0s  4s  6s  \
# 0   Dilshan Madushanka   10.0        0    80        5      8.00  25   8   2
# 1  Dushmantha Chameera   10.0        2    71        1      7.10  28   8   2
# 2        Kasun Rajitha    9.0        0    65        0      7.22  25   7   2
# 3       Angelo Mathews    3.0        0    11        0      3.66  10   1   0
# 4   Maheesh Theekshana   10.0        0    67        0      6.70  18   5   1
#
#    wd  nb       team opponent  innings  match_id
# 0   6   0  Sri Lanka    India        1         0
# 1   0   0  Sri Lanka    India        1         0
# 2   1   0  Sri Lanka    India        1         0
# 3   0   0  Sri Lanka    India        1         0
# 4   1   0  Sri Lanka    India        1         0

# %%
df.tail() #bottom 5 scales
# Out:
#            player  overs  maidens  runs  wickets  run_rate  0s  4s  6s  wd  \
# 569  David Willey   10.0        0    56        3      5.60  37   8   1   2
# 570  Chris Woakes    5.3        0    27        1      4.90  22   5   0   0
# 571   Adil Rashid   10.0        0    55        2      5.50  26   4   1   1
# 572  Gus Atkinson    8.0        0    45        2      5.62  29   3   3   2
# 573     Moeen Ali   10.0        0    60        2      6.00  27   7   1   0
#
#      nb     team  opponent  innings  match_id
# 569   0  England  Pakistan        2        47
# 570   0  England  Pakistan        2        47
# 571   0  England  Pakistan        2        47
# 572   0  England  Pakistan        2        47
# 573   0  England  Pakistan        2        47

# %%
df.isnull().sum()  #koi value null nahi hai. so, Cleaning ki necessary nahi hai
# Out:
# player      0
# overs       0
# maidens     0
# runs        0
# wickets     0
# run_rate    0
# 0s          0
# 4s          0
# 6s          0
# wd          0
# nb          0
# team        0
# opponent    0
# innings     0
# match_id    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   player    574 non-null    object
#  1   overs     574 non-null    float64
#  2   maidens   574 non-null    int64
#  3   runs      574 non-null    int64
#  4   wickets   574 non-null    int64
#  5   run_rate  574 non-null    float64
#  6   0s        574 non-null    int64
#  7   4s        574 non-null    int64
#  8   6s        574 non-null    int64
#  9   wd        574 non-null    int64
#  10  nb        574 non-null    int64
#  11  team      574 non-null    object
#  12  opponent  574 non-null    object
#  13  innings   574 non-null    int64
#  14  match_id  574 non-null    int64
# dtypes: float64(2), int64(10), object(3)
# memory usage: 67.4+ KB

# %%
df.describe()
# Out:
#             overs     maidens        runs     wickets    run_rate          0s  \
# count  574.000000  574.000000  574.000000  574.000000  574.000000  574.000000
# mean     7.351045    0.256098   42.322300    1.202091    5.922369   22.918118
# std      2.685601    0.533933   19.651473    1.193757    2.135935   10.251561
# min      0.300000    0.000000    1.000000    0.000000    1.350000    0.000000
# 25%      6.000000    0.000000   30.000000    0.000000    4.500000   16.000000
# 50%      8.000000    0.000000   41.000000    1.000000    5.660000   24.000000
# 75%     10.000000    0.000000   55.000000    2.000000    7.075000   30.000000
# max     10.000000    3.000000  115.000000    7.000000   16.000000   48.000000
#
#                4s          6s          wd          nb     innings    match_id
# count  574.000000  574.000000  574.000000  574.000000  574.000000  574.000000
# mean     3.900697    1.121951    1.158537    0.097561    1.480836   23.691638
# ...

# %%
df['team'].value_counts()
# Out:
# Australia       69
# India           64
# New Zealand     63
# Netherlands     58
# Afghanistan     55
# Sri Lanka       54
# South Africa    54
# England         53
# Bangladesh      52
# Pakistan        52
# Name: team, dtype: int64

# %% [markdown]
# ## Step 02 : Data Analysis

# %% [markdown]
# **Highest given/taken by the boweler in one spell**

# %%
# Highest runs given by a bower in 1 spell

player_name=df.loc[df['runs'].idxmax(),'player']
team_name=df.loc[df['runs'].idxmax(),'team']
highest_runs=df.loc[df['runs'].idxmax(),'runs']
opponent=df.loc[df['runs'].idxmax(),'opponent']

print("----> Highest runs were given by the bowler '",player_name, "' from the team of '", team_name,
      "' in one spell which are ",highest_runs, "against team ",opponent)


# Highest wickets taken by a bower in 1 spell
player_name=df.loc[df['wickets'].idxmax(),'player']
team_name=df.loc[df['wickets'].idxmax(),'team']
highest_wickets=df.loc[df['wickets'].idxmax(),'wickets']
opponent=df.loc[df['wickets'].idxmax(),'opponent']

print("----> Highest wickets were taken by the bowler '",player_name, "' from the team of '", team_name,
      "' in one spell which are ",highest_wickets, "against team ",opponent)

# Highest 6s given by a bower in 1 spell
player_name=df.loc[df['6s'].idxmax(),'player']
team_name=df.loc[df['6s'].idxmax(),'team']
highest_6s=df.loc[df['6s'].idxmax(),'6s']
opponent=df.loc[df['6s'].idxmax(),'opponent']

print("----> Highest 6s were given by the bowler '",player_name, "' from the team of '", team_name,
      "' in one spell which are ",highest_6s, "against team ",opponent)


# Highest 4s given by a bower in 1 spell
player_name=df.loc[df['4s'].idxmax(),'player']
team_name=df.loc[df['4s'].idxmax(),'team']
highest_4s=df.loc[df['4s'].idxmax(),'4s']
opponent=df.loc[df['4s'].idxmax(),'opponent']

print("----> Highest 4s were given by the bowler '",player_name, "' from the team of '", team_name,
      "' in one spell which are ",highest_4s, "against team ",opponent)


# Highest maiden overed by a bower in 1 spell
player_name=df.loc[df['maidens'].idxmax(),'player']
team_name=df.loc[df['maidens'].idxmax(),'team']
highest_maidens=df.loc[df['maidens'].idxmax(),'maidens']
opponent=df.loc[df['maidens'].idxmax(),'opponent']

print("----> Highest Maidens were overed by the bowler '",player_name, "' from the team of '", team_name,
      "' in one spell which are ",highest_maidens, "against team ",opponent)
# Out:
# ----> Highest runs were given by the bowler ' Bas de Leede ' from the team of ' Netherlands ' in one spell which are  115 against team  Australia
# ----> Highest wickets were taken by the bowler ' Mohammed Shami ' from the team of ' India ' in one spell which are  7 against team  New Zealand
# ----> Highest 6s were given by the bowler ' Hasan Mahmud ' from the team of ' Bangladesh ' in one spell which are  6 against team  South Africa
# ----> Highest 4s were given by the bowler ' Marco Jansen ' from the team of ' South Africa ' in one spell which are  15 against team  India
# ----> Highest Maidens were overed by the bowler ' Trent Boult ' from the team of ' New Zealand ' in one spell which are  3 against team  Sri Lanka

# %% [markdown]
# **Grouping the players**

# %%
df_player_overs=df.groupby('player').agg({'overs':'sum', 'maidens':'sum', 'runs':'sum', 'wickets':'sum', 'run_rate':'mean', '4s':'sum', '6s':'sum', 'wd':'sum'}).reset_index()
df_player_overs
# Out:
#                  player  overs  maidens  runs  wickets  run_rate  4s  6s  wd
# 0            Adam Zampa   96.0        1   515       23  5.290909  33  14   9
# 1           Adil Rashid   79.4        1   413       15  5.456667  24  11   3
# 2           Agha Salman    5.0        0    46        0  9.415000   5   2   1
# 3         Aiden Markram   18.3        1    85        1  5.480000   6   3   2
# 4    Andile Phehlukwayo    7.0        0    36        1  5.140000   4   0   0
# ..                  ...    ...      ...   ...      ...       ...  ..  ..  ..
# 97          Travis Head   21.0        0   101        2  4.460000   6   3   1
# 98          Trent Boult   91.0        6   504       14  5.535000  52  15  19
# 99            Usama Mir   35.0        0   248        4  7.050000  18  11   6
# 100     Vikramjit Singh    7.0        0    52        0  7.916667   7   1   1
# 101         Virat Kohli    3.3        0    15        1  4.165000   1   0   0
#
# [102 rows x 9 columns]

# %%
# sort the dataset by the overs
sorted_df_player_overs = df_player_overs.sort_values(by='overs', ascending=False).reset_index()
sorted_df_player_overs
# Out:
#      index                 player  overs  maidens  runs  wickets   run_rate  \
# 0        0             Adam Zampa   96.0        1   515       23   5.290909
# 1       40          Kuldeep Yadav   95.1        2   424       15   4.077273
# 2       36         Josh Hazlewood   93.1        8   449       16   4.741818
# 3       77        Ravindra Jadeja   92.9        4   398       16   4.362727
# 4       57       Mitchell Santner   92.4        4   449       16   4.958000
# ..     ...                    ...    ...      ...   ...      ...        ...
# 97      14         Daryl Mitchell    1.3        0    12        0   6.500000
# 98      11       Charith Asalanka    1.0        0    10        0  10.000000
# 99      74            Rahmat Shah    1.0        0    12        0  12.000000
# 100     67  Najmul Hossain Shanto    1.0        0     5        0   5.000000
# 101     80           Rohit Sharma    0.5        0     7        1   8.400000
#
#      4s  6s  wd
# 0    33  14   9
# 1    21  14   4
# ...

# %% [markdown]
# **PLOTTING GRAPH BW OVERS AND PLAYERS**

# %%
df_player_overs_top30=sorted_df_player_overs.head(30)
df_player_overs_top30

x=df_player_overs_top30['player']
y=df_player_overs_top30['overs']
#plotting bar graph
plt.figure(figsize=(20,10))
plt.bar(x,y)

plt.xlabel("Players name",color='r',fontsize=20)
plt.ylabel("Overs by the bowler",color='r',fontsize=20)
plt.title("OVERS BY TOP 30 PLAYERS",color='c',fontsize=20)
plt.xticks(rotation=45,ha='right',fontsize=15)
plt.tight_layout()

plt.show()

# %% [markdown]
# **RUNS GIVEN BY BOWLER**

# %%
df_player_overs_top30=sorted_df_player_overs.head(30)

#plotting
x=df_player_overs_top30['player'];
y=df_player_overs_top30['runs']

plt.figure(figsize=(20,10))
plt.bar(x,y)

plt.xlabel("Players name",color='r',fontsize=20)
plt.ylabel("Runs Given",color='r',fontsize=20)
plt.title("RUNS GIVEN BY TOP 30 PLAYERS",color='c',fontsize=20)
plt.xticks(rotation=45,ha='right',fontsize=15)
plt.grid()
plt.tight_layout()

plt.show()

# %% [markdown]
# **RUNRATE**

# %%
df_player_overs_top30=sorted_df_player_overs.head(30)

#plotting
x=df_player_overs_top30['player'];
y=df_player_overs_top30['run_rate']

plt.figure(figsize=(20,10))
plt.bar(x,y)

plt.xlabel("Players name",color='r',fontsize=20)
plt.ylabel("Run Rate",color='r',fontsize=20)
plt.title("RUNRATE BY TOP 30 PLAYERS",color='c',fontsize=20)
plt.xticks(rotation=45,ha='right',fontsize=15)
plt.grid()
plt.tight_layout()

plt.show()

# %% [markdown]
# **WIDE GIVEN**

# %%
df_player_overs_top30=sorted_df_player_overs.head(30)

#plotting
x=df_player_overs_top30['player'];
y=df_player_overs_top30['wd']

plt.figure(figsize=(20,10))
plt.bar(x,y)

plt.xlabel("Players name",color='r',fontsize=20)
plt.ylabel("Runs Given",color='r',fontsize=20)
plt.title("WIDE GIVEN BY TOP 30 PLAYERS",color='c',fontsize=20)
plt.xticks(rotation=45,ha='right',fontsize=15)
plt.grid()
plt.tight_layout()

plt.show()

# %% [markdown]
# **MAIDEN OVERS AND OVERS FOR TOP 30 PLAYERS**

# %%
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot bars for 'overs' on the primary y-axis (ax1)

index = np.arange(len(df_player_overs_top30))
bars = ax1.bar(index, df_player_overs_top30['overs'], label='Overs', color='skyblue')

# Plot line for 'wickets' on the same y-axis (ax1)
line = ax1.plot(index, df_player_overs_top30['maidens'], color='orange', marker='o', label='maiden')

# Set labels and titles
ax1.set_xlabel('Player')
ax1.set_ylabel('Overs', color='g')
ax1.tick_params(axis='y', labelcolor='g')  # Make sure y-axis labels are in blue

plt.title('Maiden overs and Overs for the top 30 players')

# Combine legends
bars_legend = [bar for bar in bars]
line_legend = [line[0]]
plt.legend(bars_legend + line_legend, ['Overs', 'Maiden '], loc='upper left')

# Set x-axis ticks and labels
plt.xticks(index, df_player_overs_top30['player'], rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Bowlers are sorted by Wickets taken by them

# %%
sorted_df_player_wickets = df_player_overs.sort_values(by='wickets', ascending=False).reset_index()
sorted_df_player_wickets
# Out:
#      index              player  overs  maidens  runs  wickets   run_rate  4s  \
# 0       63      Mohammed Shami   48.5        4   257       24   5.138571  27
# 1        0          Adam Zampa   96.0        1   515       23   5.290909  33
# 2       18  Dilshan Madushanka   77.8        4   525       21   6.786667  63
# 3       34      Jasprit Bumrah   91.5        9   373       20   3.874545  38
# 4       23      Gerald Coetzee   63.3        1   396       20   6.442500  47
# ..     ...                 ...    ...      ...   ...      ...        ...  ..
# 97      14      Daryl Mitchell    1.3        0    12        0   6.500000   0
# 98      15       Dasun Shanaka   11.0        0    64        0   5.800000   3
# 99      74         Rahmat Shah    1.0        0    12        0  12.000000   1
# 100     20     Dushan Hemantha   16.0        0    94        0   5.875000   5
# 101     91        Shubman Gill    2.0        0    11        0   5.500000   1
#
#      6s  wd
# 0     7   9
# 1    14   9
# ...

# %% [markdown]
# ## Wickets taken by the top 30 bowlers

# %%
df_player_wickets_top_30=sorted_df_player_wickets.head(30)

# Plotting
plt.figure(figsize=(15, 6))
plt.bar(df_player_wickets_top_30['player'], df_player_wickets_top_30['wickets'], color='c')
plt.xlabel('Player')
plt.ylabel('wickets')
plt.title('wickets taken by the top 30 bowlers')
plt.xticks(rotation=45, ha='right')  # Rotate player names for better visibility
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ### Wickets and Overs for the top 30 players

# %%
for i in range(len(x)):
    plt.scatter(x[i], y[i], color='red')

# %%
# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot bars for 'overs' on the primary y-axis (ax1)

index = np.arange(len(df_player_wickets_top_30))
bars = ax1.bar(index, df_player_wickets_top_30['overs'], label='Overs', color='skyblue')

# Plot line for 'wickets' on the same y-axis (ax1)
line = ax1.plot(index, df_player_wickets_top_30['wickets'], color='orange', marker='o', label='Wickets')

# Set labels and titles
ax1.set_xlabel('Player')
ax1.set_ylabel('Overs', color='skyblue')
ax1.tick_params(axis='y', labelcolor='skyblue')  # Make sure y-axis labels are in blue

plt.title('Wickets and Overs for the top 30 players')

# Combine legends
bars_legend = [bar for bar in bars]
line_legend = [line[0]]
plt.legend(bars_legend + line_legend, ['Overs', 'Wickets'], loc='upper left')

# Set x-axis ticks and labels
plt.xticks(index, df_player_wickets_top_30['player'], rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()
